# %% [markdown]
# TravelTide Projekt - die Fortsetzung mit Clustering. [Hier ist der Link zum 1. Teil](https://github.com/Akienobob/Masterschool/blob/main/TravelTideProjektTeil1.ipynb)

# %%
import pandas as pd
url_user_features ="https://raw.githubusercontent.com/Akienobob/Masterschool/refs/heads/main/user_features.csv"
uf = pd.read_csv(url_user_features, index_col=[0])

# %%
# User-Features-Tabelle als Backup in einem anderen Dataframe kopieren
uf2=uf
uf
# Out:
#       user_id  gender  married  has_children  age  user_since  reisen_gesamt  \
# 0      531931       1    False         False   40          25              2
# 1      611065       1    False         False   43          23              4
# 2      586762       1    False         False   37          24              3
# 3      229330       1     True         False   48          31              4
# 4      536035       0    False         False   29          25              2
# ...       ...     ...      ...           ...  ...         ...            ...
# 5993   591155       0     True         False   42          24              2
# 5994   521235       1    False         False   35          25              5
# 5995   600351       1     True         False   48          23              2
# 5996   577044       1     True          True   55          24              3
# 5997   597300       1     True          True   37          24              2
#
#       stornierte_reisen  rooms_avg  nights_avg  hotel_price_avg  hotel_count  \
# 0                   NaN   1.500000    2.500000       492.500000          2.0
# 1                   NaN   1.500000    1.250000       407.500000          4.0
# 2                   NaN   1.333333    6.333333      1939.666667          3.0
# 3                   NaN   1.750000    1.500000       798.250000          4.0
# 4                   NaN   1.500000    1.000000       163.000000          2.0
# ...                 ...        ...         ...              ...          ...
# 5993                NaN   1.000000    3.500000       466.000000          2.0
# 5994                NaN   1.600000    4.600000       741.800000          5.0
# 5995                NaN   1.000000    4.000000      1040.000000          1.0
# 5996                NaN   1.000000    0.000000         0.000000          2.0
# 5997                NaN   1.500000    7.000000      2078.000000          2.0
#
#       seats_avg  flight_price_avg  flight_count  checked_bags_avg  \
# 0      1.500000        944.145000           2.0          0.500000
# 1      1.500000        893.192500           4.0          0.750000
# 2      1.333333        607.430000           3.0          0.333333
# 3      1.750000        387.027500           4.0          0.250000
# 4      1.500000        488.340000           2.0          0.500000
# ...         ...               ...           ...               ...
# 5993   1.000000        546.350000           1.0          1.000000
# 5994   1.800000        805.824000           5.0          1.200000
# 5995   1.000000        523.340000           2.0          0.500000
# 5996   1.333333        301.646667           3.0          0.333333
# 5997   1.500000        268.375000           2.0          0.000000
#
#       session_dauer_avg_sec
# 0                 70.875000
# 1                146.750000
# 2                116.375000
# 3                119.625000
# 4                102.750000
# ...                     ...
# 5993             115.125000
# 5994             179.875000
# 5995             112.500000
# 5996             150.111111
# 5997              83.750000
#
# [5998 rows x 17 columns]

# %% [markdown]
# # Analyse der Daten mithilfe von Seaborn-Diagrammen

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for col in uf.columns:
  sns.histplot(data=uf, x=col)
  plt.title(f'Distribution of {col}')
  plt.xlabel(col)
  plt.ylabel('Count')
  plt.show()

# %%
sns.scatterplot(data=uf, x='hotel_price_avg', y='flight_price_avg')
# Out:
# <Axes: xlabel='hotel_price_avg', ylabel='flight_price_avg'>

# %%
sns.scatterplot(data=uf, x='seats_avg', y='rooms_avg', hue='married')
# Out:
# <Axes: xlabel='seats_avg', ylabel='rooms_avg'>

# %%
sns.pairplot(data=uf, corner=True, kind='reg', diag_kind='kde')

# %%
sns.histplot(data=uf, x='married',hue='gender')
# Out:
# <Axes: xlabel='married', ylabel='Count'>

# %%
corr_matrix = uf.corr()
plt.figure(figsize=(10,10))

sns.heatmap(corr_matrix, annot= False, cmap='coolwarm', fmt='.2f',linewidths=1)

plt.title('Corellation Matrix')
plt.show()

# %%
cl = uf.drop(columns=['user_id','user_since'])
cl.head()
# Out:
#    gender  married  has_children  age  reisen_gesamt  stornierte_reisen  \
# 0       1    False         False   40              2                NaN
# 1       1    False         False   43              4                NaN
# 2       1    False         False   37              3                NaN
# 3       1     True         False   48              4                NaN
# 4       0    False         False   29              2                NaN
#
#    rooms_avg  nights_avg  hotel_price_avg  hotel_count  seats_avg  \
# 0   1.500000    2.500000       492.500000          2.0   1.500000
# 1   1.500000    1.250000       407.500000          4.0   1.500000
# 2   1.333333    6.333333      1939.666667          3.0   1.333333
# 3   1.750000    1.500000       798.250000          4.0   1.750000
# 4   1.500000    1.000000       163.000000          2.0   1.500000
#
#    flight_price_avg  flight_count  checked_bags_avg  session_dauer_avg_sec
# 0          944.1450           2.0          0.500000                 70.875
# 1          893.1925           4.0          0.750000                146.750
# 2          607.4300           3.0          0.333333                116.375
# 3          387.0275           4.0          0.250000                119.625
# 4          488.3400           2.0          0.500000                102.750

# %%
binary_cols = ['married', 'has_children', 'gender']
cl[binary_cols] = cl[binary_cols].astype('int64')
cl= cl.fillna(0)

# %%
cl.head()
# Out:
#    gender  married  has_children  age  reisen_gesamt  stornierte_reisen  \
# 0       1        0             0   40              2                0.0
# 1       1        0             0   43              4                0.0
# 2       1        0             0   37              3                0.0
# 3       1        1             0   48              4                0.0
# 4       0        0             0   29              2                0.0
#
#    rooms_avg  nights_avg  hotel_price_avg  hotel_count  seats_avg  \
# 0   1.500000    2.500000       492.500000          2.0   1.500000
# 1   1.500000    1.250000       407.500000          4.0   1.500000
# 2   1.333333    6.333333      1939.666667          3.0   1.333333
# 3   1.750000    1.500000       798.250000          4.0   1.750000
# 4   1.500000    1.000000       163.000000          2.0   1.500000
#
#    flight_price_avg  flight_count  checked_bags_avg  session_dauer_avg_sec
# 0          944.1450           2.0          0.500000                 70.875
# 1          893.1925           4.0          0.750000                146.750
# 2          607.4300           3.0          0.333333                116.375
# 3          387.0275           4.0          0.250000                119.625
# 4          488.3400           2.0          0.500000                102.750

# %% [markdown]
# # Werte scalieren

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_scaled = scaler.fit_transform(cl)

# %%
df_scaled
# Out:
# array([[ 0.35243071, -0.88726925, -0.69617057, ..., -0.12756393,
#          0.02824663, -1.24421676],
#        [ 0.35243071, -0.88726925, -0.69617057, ...,  1.19048677,
#          0.55790722,  0.88324179],
#        [ 0.35243071, -0.88726925, -0.69617057, ...,  0.53146142,
#         -0.32486043,  0.0315574 ],
#        ...,
#        [ 0.35243071,  1.1270536 , -0.69617057, ..., -0.12756393,
#          0.02824663, -0.0770937 ],
#        [ 0.35243071,  1.1270536 ,  1.43642958, ...,  0.53146142,
#         -0.32486043,  0.97748396],
#        [ 0.35243071,  1.1270536 ,  1.43642958, ..., -0.12756393,
#         -1.03107455, -0.88321473]])

# %%
import plotly.express as px

from sklearn.decomposition import PCA
import numpy as np
from sklearn.cluster import KMeans

# %% [markdown]
# # Dimensionen mit Principal Components Analysie reduzieren

# %%
pca = PCA(n_components=10)
pca_result = pca.fit_transform(df_scaled)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.2635939 , 0.12807341, 0.10298061, 0.0932602 , 0.07338278,
#        0.0660522 , 0.06408058, 0.04838283, 0.04229121, 0.03888104])

# %% [markdown]
# # Wieviele Dimensionen soll man behalten? cumsum zeigt, wieviele Informationen man jeweils behält

# %%
np.cumsum(pca.explained_variance_ratio_)
# Out:
# array([0.2635939 , 0.39166731, 0.49464792, 0.58790812, 0.6612909 ,
#        0.7273431 , 0.79142368, 0.8398065 , 0.88209771, 0.92097875])

# %%
px.scatter_3d(pca_result, x=0, y=1, z=2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cd158443-290d-4c3f-9c2c-38c3d64cfe0b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd158443-290d-4c3f-9c2c-38c3d64cfe0b")) {                    Plotly.newPlot(                        "cd158443-290d-4c3f-9c2c-38c3d64cfe0b",                        [{"hovertemplate":"0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[0.09570827599883662,2.487421173222474,1.1032402485354174,2.248076070239956,-0.04107676698798098,2.8705944874093716,-0.06725783605854463,0.28761161710967414,2.0094705422916754,-1.8459065779816846,0.535706706298139,1.3455884934376228,0.44792342095763915,1.7756795277043116,-2.033989304089624,1.0538941870379621,3.361647920015032,-1.6467375373064326,-0.33453824561407963,-0.9881007789795192,-1.4950822793956586,-0.9592790859341128,-1.8920466948930892,-4.286069357697678,1.4918658187957945,0.8202391606922804,-0.18691567731818284,1.7355552663738236,1.5652501022649978,1.8741088052228256,1.3936867567956601,-4.423269654154644,0.2380567196467662,2.327598759047921,-3.988342608464739,-1.5096629050251287,-0.3210479018160436,2.557707175076494,1.1331061879193893,-2.548430960692096,0.3105161848074949,-0.6869985945224613,-1.9248880850195729,0.3675940363275877,1.9043606807476552,0.7831431390602128,1.2875487528465115,-0.7771617450256613,1.6407833040401174,1.3968524955166162,-4.19143619375749,-0.9047037502369429,0.5548729611233132,1.0060019892385057,-0.10940605914054158,-2.7404250172659674,2.3965244358499693,3.086597142792014,-0.8410857752533488,-4.572642760327883,0.6429314172659675,2.816324851010912,1.1753362185403913,-0.4979011896049372,-3.2444454795483364,0.723787290401334,0.3291437696814243,-1.7562298734194743,-2.876706057964062,-0.29830274363798537,-0.25959055028256717,0.191225191500669,-4.711897890777348,1.90622003226134,0.9532131502141148,1.492274385705745,-1.7973700739717369,-1.0591861625755066,-1.2348833148745315,1.121188348051926,1.5157009645933004,-0.33059032746010975,1.1536186377055182,0.27831916526025713,-4.348870243696215,2.248868411773137,-0.921922268495556,0.6288020237757164,2.080324188729327,-0.498696860638598,-0.5844768473540517,-0.9986187024613082,-0.48326455945061264,1.4500749035796001,-0.6759075225963526,2.193582786058727,1.3271266238056532,0.0886944960230451,-0.5265893025236523,-0.9386147587648302,-1.8121003556715145,1.4040097961264528,0.34144953170963127,-0.45792549673863236,-0.29499506071426884,1.7507538957399977,0.7668437859358205,2.05177326428464,-1.3358760565325045,-0.8828008968635238,-0.7810198293939614,-3.7440403614332824,0.34987496066005486,0.23068266735211843,1.4799260825215692,-0.4346074989695297,1.6301098391421807,-4.186280801635021,-4.019266480767171,0.3176083973124178,0.8173715406042468,0.5004783441306035,1.0357860713015368,1.660492597057355,1.300652972161521,0.7053383748176846,-0.9781186254553146,1.0947980590935573,1.5844114491646863,1.1225454259763081,3.3251567408735294,-4.128078706208928,0.41091267948767785,0.1695936775657241,2.5588176411448074,-0.19717685843934937,-4.046617375214331,2.5087087017009213,0.8772322165776741,0.9635881437213523,-1.7706218803396547,-2.302454272932153,-1.141730092393855,1.4507095252719335,-0.3943380917278024,1.4655139302506326,0.8781672647719777,-4.162360491238913,0.1389041276059178,-4.686549899538284,1.1126883747055485,2.402984978544995,-1.1760393070351192,-0.46915511465964416,-0.4882199723091095,1.1172807458125997,1.2382638295381523,-4.210695589552694,0.5588145437888226,1.2437589449520594,0.31771781376183716,-0.41764477171952175,1.5734391352618606,1.9729469209078325,-4.641958332960533,1.398460310352 ...

# %% [markdown]
# # Mit Kmeans Clustering alle Benutzer in 5 Gruppen teilen, um sie weiter zu analysieren.

# %%
from sklearn.cluster import KMeans

# %%
X = df_scaled
km = KMeans(n_clusters=5)
km.fit(X)
# Out:
# KMeans(n_clusters=5)

# %%
km.labels_
# Out:
# array([2, 1, 1, ..., 2, 2, 4], dtype=int32)

# %%
cl['cluster'] = km.labels_

# %%
cl
# Out:
#       gender  married  has_children  age  reisen_gesamt  stornierte_reisen  \
# 0          1        0             0   40              2                0.0
# 1          1        0             0   43              4                0.0
# 2          1        0             0   37              3                0.0
# 3          1        1             0   48              4                0.0
# 4          0        0             0   29              2                0.0
# ...      ...      ...           ...  ...            ...                ...
# 5993       0        1             0   42              2                0.0
# 5994       1        0             0   35              5                0.0
# 5995       1        1             0   48              2                0.0
# 5996       1        1             1   55              3                0.0
# 5997       1        1             1   37              2                0.0
#
#       rooms_avg  nights_avg  hotel_price_avg  hotel_count  seats_avg  \
# 0      1.500000    2.500000       492.500000          2.0   1.500000
# 1      1.500000    1.250000       407.500000          4.0   1.500000
# 2      1.333333    6.333333      1939.666667          3.0   1.333333
# 3      1.750000    1.500000       798.250000          4.0   1.750000
# 4      1.500000    1.000000       163.000000          2.0   1.500000
# ...         ...         ...              ...          ...        ...
# 5993   1.000000    3.500000       466.000000          2.0   1.000000
# 5994   1.600000    4.600000       741.800000          5.0   1.800000
# 5995   1.000000    4.000000      1040.000000          1.0   1.000000
# 5996   1.000000    0.000000         0.000000          2.0   1.333333
# 5997   1.500000    7.000000      2078.000000          2.0   1.500000
#
#       flight_price_avg  flight_count  checked_bags_avg  session_dauer_avg_sec  \
# 0           944.145000           2.0          0.500000              70.875000
# 1           893.192500           4.0          0.750000             146.750000
# 2           607.430000           3.0          0.333333             116.375000
# 3           387.027500           4.0          0.250000             119.625000
# 4           488.340000           2.0          0.500000             102.750000
# ...                ...           ...               ...                    ...
# 5993        546.350000           1.0          1.000000             115.125000
# 5994        805.824000           5.0          1.200000             179.875000
# 5995        523.340000           2.0          0.500000             112.500000
# 5996        301.646667           3.0          0.333333             150.111111
# 5997        268.375000           2.0          0.000000              83.750000
#
#       cluster
# 0           2
# 1           1
# 2           1
# 3           1
# 4           3
# ...       ...
# 5993        3
# 5994        1
# 5995        2
# 5996        2
# 5997        4
#
# [5998 rows x 16 columns]

# %% [markdown]
# # Wieviele Benutzer gibt es in jeder Gruppe?

# %%
cl['cluster'].value_counts()
# Out:
# cluster
# 2    2406
# 1    1796
# 0     697
# 3     582
# 4     517
# Name: count, dtype: int64

# %%
cl.mean()
# Out:
# gender                     0.885962
# married                    0.440480
# has_children               0.326442
# age                       42.453151
# reisen_gesamt              2.784595
# stornierte_reisen          0.101701
# rooms_avg                  1.066790
# nights_avg                 3.323326
# hotel_price_avg          720.697145
# hotel_count                2.316772
# seats_avg                  0.997519
# flight_price_avg         389.426226
# flight_count               2.193565
# checked_bags_avg           0.486668
# session_dauer_avg_sec    115.249517
# cluster                    1.737579
# dtype: float64

# %%
cl.groupby('cluster').mean()
# Out:
#            gender   married  has_children        age  reisen_gesamt  \
# cluster
# 0        0.893831  0.378766      0.334290  38.090387       0.545194
# 1        0.994989  0.412584      0.246659  44.020601       4.418151
# 2        1.002078  0.492103      0.383209  42.744389       2.338736
# 3        0.000000  0.408935      0.340206  43.072165       3.054983
# 4        0.953578  0.415861      0.313346  40.837524       1.899420
#
#          stornierte_reisen  rooms_avg  nights_avg  hotel_price_avg  \
# cluster
# 0                 0.167862   0.114778    0.370158        48.071019
# 1                 0.095768   1.171522    3.236716       662.720894
# 2                 0.082294   1.171481    2.987185       582.945899
# 3                 0.121993   1.179954    3.247881       694.355498
# 4                 0.100580   1.371825    9.254803      2499.625758
#
#          hotel_count  seats_avg  flight_price_avg  flight_count  \
# cluster
# 0           0.114778   0.097561         36.623953      0.101865
# 1           3.851893   1.162436        423.129412      3.789532
# 2           1.917706   1.206221        495.182332      1.891937
# 3           2.518900   1.169044        467.868808      2.450172
# 4           1.582205   0.473565        167.510343      0.584139
#
#          checked_bags_avg  session_dauer_avg_sec
# cluster
# 0                0.038020              84.735236
# 1                0.554305             142.285126
# 2                0.607786             106.120323
# 3                0.578036             120.562300
# 4                0.190039              98.973509

# %% [markdown]
# # Ursprüngliche User-Id hinzufügen, damit der Auftraggeber sie indentifizieren und anmailen kann

# %%
#vorsichtshalber einen neuen DataFrame erstellen
cl2=cl
cl2['user_id']=uf2['user_id']
cl2.head(10)
# Out:
#    gender  married  has_children  age  reisen_gesamt  stornierte_reisen  \
# 0       1        0             0   40              2                0.0
# 1       1        0             0   43              4                0.0
# 2       1        0             0   37              3                0.0
# 3       1        1             0   48              4                0.0
# 4       0        0             0   29              2                0.0
# 5       1        0             0   46              5                0.0
# 6       1        0             0   39              3                0.0
# 7       1        1             1   42              3                0.0
# 8       1        0             0   39              5                0.0
# 9       1        1             1   49              1                0.0
#
#    rooms_avg  nights_avg  hotel_price_avg  hotel_count  seats_avg  \
# 0   1.500000    2.500000       492.500000          2.0   1.500000
# 1   1.500000    1.250000       407.500000          4.0   1.500000
# 2   1.333333    6.333333      1939.666667          3.0   1.333333
# 3   1.750000    1.500000       798.250000          4.0   1.750000
# 4   1.500000    1.000000       163.000000          2.0   1.500000
# 5   1.200000    3.600000      1074.000000          5.0   1.200000
# 6   1.000000    4.000000       720.333333          3.0   1.000000
# 7   1.000000    2.666667       294.666667          3.0   1.000000
# 8   1.200000    6.800000       890.000000          5.0   1.000000
# 9   1.000000    1.000000       121.000000          1.0   1.000000
#
#    flight_price_avg  flight_count  checked_bags_avg  session_dauer_avg_sec  \
# 0        944.145000           2.0          0.500000                 70.875
# 1        893.192500           4.0          0.750000                146.750
# 2        607.430000           3.0          0.333333                116.375
# 3        387.027500           4.0          0.250000                119.625
# 4        488.340000           2.0          0.500000                102.750
# 5        697.142000           5.0          0.000000                171.750
# 6        202.276667           3.0          0.000000                 91.500
# 7        482.623333           3.0          0.666667                 88.250
# 8        459.085000           2.0          0.000000                196.750
# 9        394.550000           1.0          0.000000                 81.875
#
#    cluster  user_id
# 0        2   531931
# 1        1   611065
# 2        1   586762
# 3        1   229330
# 4        3   536035
# 5        1   477730
# 6        2   513030
# 7        2   570821
# 8        1   517076
# 9        2   585248

# %%
cl2.describe()
# Out:
#             gender      married  has_children          age  reisen_gesamt  \
# count  5998.000000  5998.000000   5998.000000  5998.000000    5998.000000
# mean      0.885962     0.440480      0.326442    42.453151       2.784595
# std       0.323603     0.496486      0.468950    12.055388       1.570621
# min       0.000000     0.000000      0.000000    18.000000       0.000000
# 25%       1.000000     0.000000      0.000000    35.000000       2.000000
# 50%       1.000000     0.000000      0.000000    43.000000       3.000000
# 75%       1.000000     1.000000      1.000000    50.000000       4.000000
# max       2.000000     1.000000      1.000000    89.000000       9.000000
#
#        stornierte_reisen    rooms_avg   nights_avg  hotel_price_avg  \
# count        5998.000000  5998.000000  5998.000000      5998.000000
# mean            0.101701     1.066790     3.323326       720.697145
# std             0.310444     0.502299     2.934004       930.796045
# min             0.000000     0.000000     0.000000      -477.000000
# 25%             0.000000     1.000000     1.500000       224.000000
# 50%             0.000000     1.000000     2.750000       478.000000
# 75%             0.000000     1.250000     4.500000       879.166667
# max             2.000000     4.000000    30.000000     14057.000000
#
#        hotel_count    seats_avg  flight_price_avg  flight_count  \
# count  5998.000000  5998.000000       5998.000000   5998.000000
# mean      2.316772     0.997519        389.426226      2.193565
# std       1.456966     0.551127        438.886395      1.517519
# min       0.000000     0.000000          0.000000      0.000000
# 25%       1.000000     1.000000        186.835625      1.000000
# 50%       2.000000     1.000000        345.503000      2.000000
# 75%       3.000000     1.200000        502.593750      3.000000
# max       8.000000     6.000000       9135.130000      8.000000
#
#        checked_bags_avg  session_dauer_avg_sec      cluster        user_id
# count       5998.000000            5998.000000  5998.000000    5998.000000
# mean           0.486668             115.249517     1.737579  545440.695565
# std            0.472040              35.667593     1.066487   64924.749760
# min            0.000000              30.666667     0.000000   23557.000000
# 25%            0.000000              90.555556     1.000000  517152.000000
# 50%            0.500000             111.500000     2.000000  540542.000000
# 75%            0.800000             136.000000     2.000000  574146.000000
# max            5.000000             431.333333     4.000000  844489.000000

# %% [markdown]
# # Kreis-Diagramm

# %%
cl['cluster'].value_counts().plot(kind='pie', colormap='Pastel1')
plt.xlabel= ''
plt.titel= 'Anteile'
plt.show()

# %% [markdown]
# # Grupppen als Balkendiagramm darstellen

# %%
counts=cl2['cluster'].value_counts()
sns.barplot(x=counts.index, y = counts.values, palette ='viridis')
plt.xlabel='Gruppen'
plt.ylabel='Anzahl der Kunden'
plt.title='Verteilung'
plt.show()
# Out:
# <ipython-input-33-7f56f5d8df11>:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
result= cl2.sort_values('cluster')
print(result)
# Out:
#       gender  married  has_children  age  reisen_gesamt  stornierte_reisen  \
# 4815       1        1             0   69              0                0.0
# 5559       0        1             1   33              0                0.0
# 2785       1        0             1   46              0                0.0
# 5555       1        1             1   55              0                0.0
# 2781       1        1             0   40              1                0.0
# ...      ...      ...           ...  ...            ...                ...
# 1580       1        0             1   22              1                0.0
# 1578       1        0             1   27              1                0.0
# 4868       1        0             1   26              3                0.0
# 4880       1        0             0   45              3                0.0
# 5997       1        1             1   37              2                0.0
#
#       rooms_avg  nights_avg  hotel_price_avg  hotel_count  seats_avg  \
# 4815   0.000000    0.000000         0.000000          0.0        0.0
# 5559   0.000000    0.000000         0.000000          0.0        0.0
# 2785   0.000000    0.000000         0.000000          0.0        0.0
# 5555   0.000000    0.000000         0.000000          0.0        0.0
# 2781   1.000000    2.000000       274.000000          1.0        0.0
# ...         ...         ...              ...          ...        ...
# 1580   1.000000   10.000000      1730.000000          1.0        0.0
# 1578   1.000000   11.000000      1705.000000          1.0        0.0
# 4868   1.666667   10.333333      1586.000000          3.0        0.0
# 4880   1.000000    9.333333      3991.333333          3.0        1.0
# 5997   1.500000    7.000000      2078.000000          2.0        1.5
#
#       flight_price_avg  flight_count  checked_bags_avg  session_dauer_avg_sec  \
# 4815          0.000000           0.0               0.0                 59.375
# 5559          0.000000           0.0               0.0                 55.750
# 2785          0.000000           0.0               0.0                214.375
# 5555          0.000000           0.0               0.0                 75.750
# 2781          0.000000           0.0               0.0                 77.375
# ...                ...           ...               ...                    ...
# 1580          0.000000           0.0               0.0                131.625
# 1578          0.000000           0.0               0.0                100.500
# 4868          0.000000           0.0               0.0                 97.500
# 4880        274.713333           3.0               1.0                150.000
# 5997        268.375000           2.0               0.0                 83.750
#
#       cluster  user_id
# 4815        0   566002
# 5559        0   576785
# 2785        0   494441
# 5555        0   587233
# 2781        0   619971
# ...       ...      ...
# 1580        4   529677
# 1578        4   535994
# 4868        4   549390
# 4880        4   537123
# 5997        4   597300
#
# [5998 rows x 17 columns]

# %% [markdown]
# # Ergebnis - sortierte Datei mit Usergruppen - als .csv exportieren

# %%
result.to_csv('sortierte_gruppen.csv', index=False)

# %%
result.to_csv('sortierte_gruppen_semicolon.csv', index=False, sep=';')

# %% [markdown]
# # Optional: die segmentierte User-Features Tabelle mit der ursprünglichen User-Tabelle mergen, um sich die Daten nochmal anzuschauen

# %%
url_users ="https://raw.githubusercontent.com/Akienobob/Masterschool/refs/heads/main/users.csv"
users = pd.read_csv(url_users)

# %%
result_mit_users = users.merge(result, how='inner', on='user_id')

# %%
result_mit_users.to_csv('sortierte_gruppen_mit_benutzerdaten.csv', index=False)

# %%
result_mit_users.to_csv('sortierte_gruppen_mit_benutzerdaten_semicolon.csv', index=False, sep=';')
